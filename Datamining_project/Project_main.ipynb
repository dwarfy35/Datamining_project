# %%
import numpy as np
import sklearn as skl
import matplotlib as mpl
import pandas as pd
import os

# %%
path_old = os.getcwd()
path = path_old +"//Data"
os.chdir(path) # Probably smarter way to this but it should work (for windows)
data = pd.read_csv("2014_LoL_esports_match_data_from_OraclesElixir.csv")
os.chdir(path_old)
